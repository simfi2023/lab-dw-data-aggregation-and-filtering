# %% [markdown]
# # Lab | Data Aggregation and Filtering

# %% [markdown]
# In this challenge, we will continue to work with customer data from an insurance company. We will use the dataset called marketing_customer_analysis.csv, which can be found at the following link:
#
# https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis.csv
#
# This dataset contains information such as customer demographics, policy details, vehicle information, and the customer's response to the last marketing campaign. Our goal is to explore and analyze this data by first performing data cleaning, formatting, and structuring.

# %%
import numpy as np 
import pandas as pd

data = pd.read_csv('https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis.csv')

# %%
data.head()

#data.shape --> (10910, 26)
# Out:
#    Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0           0  DK49336     Arizona              4809.216960       No
# 1           1  KX64629  California              2228.525238       No
# 2           2  LZ68649  Washington             14947.917300       No
# 3           3  XL78013      Oregon             22332.439460      Yes
# 4           4  QA50777      Oregon              9025.067525       No
#
#    Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# 0     Basic   College           2/18/11         Employed      M  ...
# 1     Basic   College           1/18/11       Unemployed      F  ...
# 2     Basic  Bachelor           2/10/11         Employed      M  ...
# 3  Extended   College           1/11/11         Employed      M  ...
# 4   Premium  Bachelor           1/17/11    Medical Leave      F  ...
#
#    Number of Open Complaints Number of Policies     Policy Type        Policy  \
# ...

# %%
##1. CLEANING

cols = []
for colname in data.columns:
    cols.append(colname.lower())

data.columns = cols

##1.1 CLEANING COLUMN NAMES

#Delete unnamed column 
def delete_unamed_column(df: pd.DataFrame) -> pd.DataFrame:
    '''
    This function takes a Pandas DataFrame as input, and creates an internal copy.
    Then on the interal copy it checks wheter or not contains a column named "Unnamed: 0".
    If it exists, deletes the column and returns the modified DataFrame, otherwise returns
    the original DataFrame.

    Inputs:
    df: Pandas DataFrame

    Output:
    Modified Pandas DataFrame
    '''

    df2 = df.copy()

    if "unnamed: 0" in df2.columns:
        df2 = df2.drop("unnamed: 0", axis=1)
        
    return df2
    
data = delete_unamed_column(data)


#White spaces in column names should be replaced by _

for colname in data:
     data.columns = data.columns.str.replace(" ", "_")

        
data.head()
# Out:
#   customer       state  customer_lifetime_value response  coverage education  \
# 0  DK49336     Arizona              4809.216960       No     Basic   College
# 1  KX64629  California              2228.525238       No     Basic   College
# 2  LZ68649  Washington             14947.917300       No     Basic  Bachelor
# 3  XL78013      Oregon             22332.439460      Yes  Extended   College
# 4  QA50777      Oregon              9025.067525       No   Premium  Bachelor
#
#   effective_to_date employmentstatus gender  income  ...  \
# 0           2/18/11         Employed      M   48029  ...
# 1           1/18/11       Unemployed      F       0  ...
# 2           2/10/11         Employed      M   22139  ...
# 3           1/11/11         Employed      M   49078  ...
# 4           1/17/11    Medical Leave      F   23675  ...
#
#   number_of_open_complaints number_of_policies     policy_type        policy  \
# 0                       0.0                  9  Corporate Auto  Corporate L3
# ...

# %%
##1.2 FORMATTING DATA TYPES

print(data.dtypes)

#todo: 
#- effective_to_date should be a datetime

data['effective_to_date'] = pd.to_datetime(data['effective_to_date'], errors='coerce')
# Out:
# customer                          object
# state                             object
# customer_lifetime_value          float64
# response                          object
# coverage                          object
# education                         object
# effective_to_date                 object
# employmentstatus                  object
# gender                            object
# income                             int64
# location_code                     object
# marital_status                    object
# monthly_premium_auto               int64
# months_since_last_claim          float64
# months_since_policy_inception      int64
# number_of_open_complaints        float64
# number_of_policies                 int64
# policy_type                       object
# policy                            object
# renew_offer_type                  object
# sales_channel                     object
# total_claim_amount               float64
# vehicle_class                     object
# ...

# %%
##1.3 CLEANING INVALID VALUES

data.nunique()

##number_of_open_complaints seems wrong

print(data["number_of_open_complaints"].unique()) ##apparently they all have a .0 which can be deleted --> they are unnesseceraly a float

data["number_of_open_complaints"] = data["number_of_open_complaints"].fillna(-1)
data["number_of_open_complaints"] = data["number_of_open_complaints"].astype(int)
data["number_of_open_complaints"] = data["number_of_open_complaints"].replace(-1, pd.NA)

data.head(10)


def convert_numeric(df: pd.DataFrame, column_name: object) -> pd.DataFrame:
    
    df2 = df.copy()
    
    df2[column_name] = df2[column_name].round(0).astype(int)
    
    df2[column_name] = pd.to_numeric(df2[column_name], downcast="integer", errors='coerce')

    return df2  
    
    
data = convert_numeric(data, "total_claim_amount")

data = convert_numeric(data, "customer_lifetime_value")

data.head()
# Out:
# [ 0. nan  3.  1.  2.  4.  5.]
#   customer       state  customer_lifetime_value response  coverage education  \
# 0  DK49336     Arizona                     4809       No     Basic   College
# 1  KX64629  California                     2229       No     Basic   College
# 2  LZ68649  Washington                    14948       No     Basic  Bachelor
# 3  XL78013      Oregon                    22332      Yes  Extended   College
# 4  QA50777      Oregon                     9025       No   Premium  Bachelor
#
#   effective_to_date employmentstatus gender  income  ...  \
# 0        2011-02-18         Employed      M   48029  ...
# 1        2011-01-18       Unemployed      F       0  ...
# 2        2011-02-10         Employed      M   22139  ...
# 3        2011-01-11         Employed      M   49078  ...
# 4        2011-01-17    Medical Leave      F   23675  ...
#
#   number_of_open_complaints number_of_policies     policy_type        policy  \
# ...

# %%
##1.4 DEALING WITH NULL VALUES

data.isnull().sum()

missing_values_df = pd.DataFrame(round(data.isna().sum()/len(file1),4)*100)
missing_values_df = missing_values_df.reset_index()
missing_values_df.columns = ['column_name', 'percentage_of_missing_values']
#display(missing_values_df)

##The percentage of most missing values is quite small, so I will drop them if NA < 5.80%

columns_with_NA = ['state', 'response', 'months_since_last_claim', 'number_of_open_complaints', 'vehicle_class', 'vehicle_size']

rows_to_drop = data[data[columns_with_NA].isna().any(axis=1)].index
data = data.drop(rows_to_drop, axis=0)

##In vehicle_type more than 50% of the Data is missing

data["vehicle_type"].unique() #apparently there is only 1 unique value which is "A", so I'm replacing the missing values with this 1 unique value

data['vehicle_type'] = data['vehicle_type'].fillna("A")

display(data.head())

##Check again for missing values: 
display(data.isnull().sum())
# Out:
#   customer       state  customer_lifetime_value response  coverage education  \
# 0  DK49336     Arizona                     4809       No     Basic   College
# 1  KX64629  California                     2229       No     Basic   College
# 2  LZ68649  Washington                    14948       No     Basic  Bachelor
# 3  XL78013      Oregon                    22332      Yes  Extended   College
# 6  IW72280  California                     5035       No     Basic    Doctor
#
#   effective_to_date employmentstatus gender  income  ...  \
# 0        2011-02-18         Employed      M   48029  ...
# 1        2011-01-18       Unemployed      F       0  ...
# 2        2011-02-10         Employed      M   22139  ...
# 3        2011-01-11         Employed      M   49078  ...
# 6        2011-02-14         Employed      F   37405  ...
#
#   number_of_open_complaints number_of_policies     policy_type        policy  \
# 0                         0                  9  Corporate Auto  Corporate L3
# ...

# %%
#Cleaned dataframe

data.head()
# Out:
#   customer       state  customer_lifetime_value response  coverage education  \
# 0  DK49336     Arizona                     4809       No     Basic   College
# 1  KX64629  California                     2229       No     Basic   College
# 2  LZ68649  Washington                    14948       No     Basic  Bachelor
# 3  XL78013      Oregon                    22332      Yes  Extended   College
# 6  IW72280  California                     5035       No     Basic    Doctor
#
#   effective_to_date employmentstatus gender  income  ...  \
# 0        2011-02-18         Employed      M   48029  ...
# 1        2011-01-18       Unemployed      F       0  ...
# 2        2011-02-10         Employed      M   22139  ...
# 3        2011-01-11         Employed      M   49078  ...
# 6        2011-02-14         Employed      F   37405  ...
#
#   number_of_open_complaints number_of_policies     policy_type        policy  \
# 0                         0                  9  Corporate Auto  Corporate L3
# ...

# %% [markdown]
# 1. Create a new DataFrame that only includes customers who have a total_claim_amount greater than $1,000 and have a response of "Yes" to the last marketing campaign.

# %%
new_data = data[(data['total_claim_amount'] > 1000) & (data['response'] == 'Yes')]

print(display(new_data.head()))
print(new_data.shape)
# Out:
#     customer       state  customer_lifetime_value response  coverage  \
# 189  OK31456  California                    11009      Yes   Premium
# 236  YJ16163      Oregon                    11009      Yes   Premium
# 419  GW43195      Oregon                    25807      Yes  Extended
# 442  IP94270     Arizona                    13736      Yes   Premium
# 587  FJ28407  California                     5620      Yes   Premium
#
#                 education effective_to_date employmentstatus gender  income  \
# 189              Bachelor        2011-01-24         Employed      F   51643
# 236              Bachelor        2011-01-24         Employed      F   51643
# 419               College        2011-02-13         Employed      F   71210
# 442                Master        2011-02-13         Disabled      F   16181
# 587  High School or Below        2011-01-26       Unemployed      M       0
#
#      ... number_of_open_complaints number_of_policies     policy_type  \
# ...

# %% [markdown]
# 2. Using the original Dataframe, analyze the average total_claim_amount by each policy type and gender for customers who have responded "Yes" to the last marketing campaign. Write your conclusions.

# %%
data[data['response'] == 'Yes'].groupby(["policy_type", "gender"]).agg({'total_claim_amount':'mean'})
# Out:
#                        total_claim_amount
# policy_type    gender
# Corporate Auto F               431.489933
#                M               412.733813
# Personal Auto  F               454.102296
#                M               453.574113
# Special Auto   F               455.656250
#                M               414.800000

# %% [markdown]
# 3. Analyze the total number of customers who have policies in each state, and then filter the results to only include states where there are more than 500 customers.

# %%
data_customers_state = data.groupby(["state"]).agg({"customer": "count"}).reset_index()

data_customers_state = data_customers_state[data_customers_state["customer"] > 500]

display(data_customers_state)
# Out:
#         state  customer
# 0     Arizona      1703
# 1  California      3150
# 2      Nevada       882
# 3      Oregon      2601
# 4  Washington       798

# %% [markdown]
# 4. Find the maximum, minimum, and median customer lifetime value by education level and gender. Write your conclusions.

# %%
data.groupby(["education", "gender"]).agg({"customer_lifetime_value": ["min", "max", "median"]})
# Out:
#                             customer_lifetime_value
#                                                 min    max  median
# education            gender
# Bachelor             F                         1904  73226  5678.0
#                      M                         1898  67907  5556.0
# College              F                         1899  61850  5622.0
#                      M                         1918  61135  5990.0
# Doctor               F                         2396  44856  5332.0
#                      M                         2268  32677  5621.0
# High School or Below F                         2145  55277  6044.0
#                      M                         1941  83325  6177.0
# Master               F                         2418  51016  5801.0
#                      M                         2272  50568  5618.0

# %% [markdown]
# ## Bonus

# %% [markdown]
# 5. The marketing team wants to analyze the number of policies sold by state and month. Present the data in a table where the months are arranged as columns and the states are arranged as rows.

# %% [markdown]
# 6.  Display a new DataFrame that contains the number of policies sold by month, by state, for the top 3 states with the highest number of policies sold.
#
# *Hint:*
# - *To accomplish this, you will first need to group the data by state and month, then count the number of policies sold for each group. Afterwards, you will need to sort the data by the count of policies sold in descending order.*
# - *Next, you will select the top 3 states with the highest number of policies sold.*
# - *Finally, you will create a new DataFrame that contains the number of policies sold by month for each of the top 3 states.*

# %% [markdown]
# 7. The marketing team wants to analyze the effect of different marketing channels on the customer response rate.
#
# Hint: You can use melt to unpivot the data and create a table that shows the customer response rate (those who responded "Yes") by marketing channel.

# %% [markdown]
# External Resources for Data Filtering: https://towardsdatascience.com/filtering-data-frames-in-pandas-b570b1f834b9

# %%
# your code goes here
